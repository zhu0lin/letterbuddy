# %%
import cv2 as cv

img = None

#define all needed functions
import os
import glob
import shutil

def extract_characters_from_image(image): #results in /results
    img = cv.imread(image)
    if img is None:
        print(f"Error: Could not read image {image}")
        return

    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    #cv.imshow('gray image', gray)

    # Optional: improve contrast
    gray = cv.equalizeHist(gray)

    # Threshold (adaptive) – keep text white, background black
    thresh = cv.adaptiveThreshold(
        gray, 255,
        cv.ADAPTIVE_THRESH_GAUSSIAN_C,
        cv.THRESH_BINARY_INV,
        35, 10
    )
    cv.imshow('thresholded image', thresh)

    # Morphology to clean noise (larger kernel)
    kernel = cv.getStructuringElement(cv.MORPH_RECT, (3,3)) #bigger numbers add background blur
    morph = cv.morphologyEx(thresh, cv.MORPH_OPEN, kernel, iterations=1)  # remove specks
    morph = cv.morphologyEx(morph, cv.MORPH_CLOSE, kernel, iterations=1)  # connect strokes
    cv.imshow('morphological image', morph)

    # Use connected components instead of contours
    num_labels, labels, stats, centroids = cv.connectedComponentsWithStats(morph, connectivity=8)

    # Visualization
    vis = cv.cvtColor(morph, cv.COLOR_GRAY2BGR)

    os.makedirs("results_training", exist_ok=True)

    for i in range(1, num_labels):  # skip background
        x, y, w, h, area = stats[i]

        # Filter blobs (remove tiny specks and very large areas)
        if area < 50 or w*h > 0.15*img.shape[0]*img.shape[1]:
            continue

        char_img = morph[y:y+h + 20, x:x+w]
        cv.imwrite(f'results_training/char_{i}.png', char_img)

        # Draw boxes for visualization
        cv.rectangle(vis, (x, y), (x+w, y+h + 10), (0, 255, 0), 1)

    cv.imshow("characters", vis)

    cv.waitKey(0)
    cv.destroyAllWindows()

def clear_folder(folder_path: str):
    """
    Clears all contents of the given folder but keeps the folder itself.
    If the folder does not exist, it will be created.
    """
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
        return

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            if os.path.isfile(file_path) or os.path.islink(file_path):
                os.remove(file_path)      # delete file or symlink
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)  # delete folder
        except Exception as e:
            print(f"Failed to delete {file_path}. Reason: {e}")

    print(f"Cleared contents of: {folder_path}")

# %%
extract_characters_from_image('./data/tests/test5.png')

# %%
def run_human_trainer():
    """
    For each image in results_training, display the image and wait for the user
    to press the key corresponding to the character they see.
    The image is then renamed to char_[user_input].png and moved to results_paired_human.
    """
    import cv2 as cv
    import os
    import shutil

    src_folder = "./results_training"
    dst_folder = "./results_paired_human"
    os.makedirs(dst_folder, exist_ok=True)

    for filename in os.listdir(src_folder):
        if filename.lower().endswith((".png", ".jpg", ".jpeg")):
            img_path = os.path.join(src_folder, filename)
            print(f"Processing: {img_path}")
            
            img = cv.imread(img_path)
            if img is None:
                print(f"Could not open {img_path}")
                continue

            # Show the image
            cv.imshow("Label this character (press key)", img)
            key = cv.waitKey(0)  # wait until a key is pressed
            cv.destroyAllWindows()

            if key == 27:  # ESC = quit
                print("Exiting labeling.")
                break
            elif key == 32:  # SPACE = skip
                print("Skipped.")
                continue
            else:
                char = chr(key)
                print(f"Labeled as: {char}")

                # Append the key to the original filename
                base, ext = os.path.splitext(filename)
                new_filename = f"{base}{char}{ext}"

                dst_path = os.path.join(dst_folder, new_filename)
                shutil.move(img_path, dst_path)
                print(f"Moved and renamed to {dst_path}")


                # # Save with new name
                # new_filename = f"char_{char}.png"
                # dst_path = os.path.join(dst_folder, new_filename)
                # shutil.move(img_path, dst_path)
                # print(f"Moved and renamed to {dst_path}")

# %%
clear_folder("./results_paired_Human")
# Out:
# Cleared contents of: ./results_paired_Human

# %%
run_human_trainer()
# Out:
# Processing: ./results_training\char_102.png
# Labeled as: N
# Moved and renamed to ./results_paired_human\char_102N.png
# Processing: ./results_training\char_105.png
# Labeled as: M
# Moved and renamed to ./results_paired_human\char_105M.png
# Processing: ./results_training\char_106.png
# Labeled as: o
# Moved and renamed to ./results_paired_human\char_106o.png
# Processing: ./results_training\char_107.png
# Labeled as: n
# Moved and renamed to ./results_paired_human\char_107n.png
# Processing: ./results_training\char_11.png
# Labeled as: d
# Moved and renamed to ./results_paired_human\char_11d.png
# Processing: ./results_training\char_110.png
# Labeled as: M
# Moved and renamed to ./results_paired_human\char_110M.png
# Processing: ./results_training\char_12.png
# Labeled as: b
# Moved and renamed to ./results_paired_human\char_12b.png
# Processing: ./results_training\char_127.png
# Labeled as: X
# Moved and renamed to ./results_paired_human\char_127X.png
# Processing: ./results_training\char_13.png
# Labeled as: e
# Moved and renamed to ./results_paired_human\char_13e.png
# Processing: ./results_training\char_130.png
# Labeled as: W
# Moved and renamed to ./results_paired_human\char_130W.png
# Processing: ./results_training\char_131.png
# Labeled as: x
# Moved and renamed to ./results_paired_human\char_131x.png
# Processing: ./results_training\char_132.png
# Labeled as: V
# Moved and renamed to ./results_paired_human\char_132V.png
# Processing: ./results_training\char_133.png
# Labeled as: w
# Moved and renamed to ./results_paired_human\char_133w.png
# Processing: ./results_training\char_134.png
# Labeled as: u
# Moved and renamed to ./results_paired_human\char_134u.png
# Processing: ./results_training\char_135.png
# Labeled as: v
# Moved and renamed to ./results_paired_human\char_135v.png
# Processing: ./results_training\char_136.png
# Labeled as: S
# Moved and renamed to ./results_paired_human\char_136S.png
# Processing: ./results_training\char_137.png
# Labeled as: T
# Moved and renamed to ./results_paired_human\char_137T.png
# Processing: ./results_training\char_139.png
# Labeled as: u
# Moved and renamed to ./results_paired_human\char_139u.png
# Processing: ./results_training\char_140.png
# Labeled as: t
# Moved and renamed to ./results_paired_human\char_140t.png
# Processing: ./results_training\char_141.png
# Labeled as: s
# Moved and renamed to ./results_paired_human\char_141s.png
# Processing: ./results_training\char_143.png
# Labeled as: Z
# Moved and renamed to ./results_paired_human\char_143Z.png
# Processing: ./results_training\char_144.png
# Labeled as: Y
# Moved and renamed to ./results_paired_human\char_144Y.png
# Processing: ./results_training\char_145.png
# Labeled as: z
# Moved and renamed to ./results_paired_human\char_145z.png
# Processing: ./results_training\char_146.png
# Labeled as: y
# Moved and renamed to ./results_paired_human\char_146y.png
# Processing: ./results_training\char_15.png
# Labeled as: a
# Moved and renamed to ./results_paired_human\char_15a.png
# Processing: ./results_training\char_16.png
# Labeled as: c
# Moved and renamed to ./results_paired_human\char_16c.png
# Processing: ./results_training\char_25.png
# Labeled as: J
# Moved and renamed to ./results_paired_human\char_25J.png
# Processing: ./results_training\char_26.png
# Labeled as: L
# Moved and renamed to ./results_paired_human\char_26L.png
# Processing: ./results_training\char_28.png
# Labeled as: l
# Moved and renamed to ./results_paired_human\char_28l.png
# Processing: ./results_training\char_3.png
# Labeled as: F
# Moved and renamed to ./results_paired_human\char_3F.png
# Processing: ./results_training\char_30.png
# Labeled as: K
# Moved and renamed to ./results_paired_human\char_30K.png
# Processing: ./results_training\char_32.png
# Labeled as: I
# Moved and renamed to ./results_paired_human\char_32I.png
# Processing: ./results_training\char_33.png
# Labeled as: H
# Moved and renamed to ./results_paired_human\char_33H.png
# Processing: ./results_training\char_35.png
# Labeled as: G
# Moved and renamed to ./results_paired_human\char_35G.png
# Processing: ./results_training\char_36.png
# Labeled as: h
# Moved and renamed to ./results_paired_human\char_36h.png
# Processing: ./results_training\char_38.png
# Labeled as: k
# Moved and renamed to ./results_paired_human\char_38k.png
# Processing: ./results_training\char_4.png
# Labeled as: D
# Moved and renamed to ./results_paired_human\char_4D.png
# Processing: ./results_training\char_40.png
# Labeled as: i
# Moved and renamed to ./results_paired_human\char_40i.png
# Processing: ./results_training\char_41.png
# Labeled as: i
# Moved and renamed to ./results_paired_human\char_41i.png
# Processing: ./results_training\char_45.png
# Labeled as: S
# Moved and renamed to ./results_paired_human\char_45S.png
# Processing: ./results_training\char_46.png
# Labeled as: g
# Moved and renamed to ./results_paired_human\char_46g.png
# Processing: ./results_training\char_47.png
# Labeled as: i
# Moved and renamed to ./results_paired_human\char_47i.png
# Processing: ./results_training\char_5.png
# Labeled as: E
# Moved and renamed to ./results_paired_human\char_5E.png
# Processing: ./results_training\char_6.png
# Labeled as: f
# Moved and renamed to ./results_paired_human\char_6f.png
# Processing: ./results_training\char_7.png
# Labeled as: A
# Moved and renamed to ./results_paired_human\char_7A.png
# Processing: ./results_training\char_78.png
# Labeled as: R
# Moved and renamed to ./results_paired_human\char_78R.png
# Processing: ./results_training\char_8.png
# Labeled as: B
# Moved and renamed to ./results_paired_human\char_8B.png
# Processing: ./results_training\char_86.png
# Labeled as: Q
# Moved and renamed to ./results_paired_human\char_86Q.png
# Processing: ./results_training\char_87.png
# Labeled as: r
# Moved and renamed to ./results_paired_human\char_87r.png
# Processing: ./results_training\char_9.png
# Labeled as: C
# Moved and renamed to ./results_paired_human\char_9C.png
# Processing: ./results_training\char_91.png
# Labeled as: P
# Moved and renamed to ./results_paired_human\char_91P.png
# Processing: ./results_training\char_96.png
# Labeled as: q
# Moved and renamed to ./results_paired_human\char_96q.png
# Processing: ./results_training\char_97.png
# Labeled as: O
# Moved and renamed to ./results_paired_human\char_97O.png
# Processing: ./results_training\char_98.png
# Labeled as: P
# Moved and renamed to ./results_paired_human\char_98P.png
